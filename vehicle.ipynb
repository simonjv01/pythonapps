# %%
# %pip install matplotlib
# %pip install pandas
# %pip install IPython
# %matplotlib inline
from IPython.display import display
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
pd.options.display.min_rows = 20

# %%
#%pip install openpyxl
import os

data_files = 'C:/Users/sjvar/Dev/pythondev/datasets/vehicles.csv'
if os.path.exists(data_files):
	autos = pd.read_csv(data_files)
	display(autos)
else:
	print(f"File not found: {data_files}")
# Out:
# C:\Users\sjvar\AppData\Local\Temp\ipykernel_28064\340024091.py:6: DtypeWarning: Columns (74,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   autos = pd.read_csv(data_files)
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      14.167143         0.0        0.0        0.0      19      0.0        0
# 1      27.046364         0.0        0.0        0.0       9      0.0        0
# 2      11.018889         0.0        0.0        0.0      23      0.0        0
# 3      27.046364         0.0        0.0        0.0      10      0.0        0
# 4      15.658421         0.0        0.0        0.0      17      0.0        0
# 5      13.523182         0.0        0.0        0.0      21      0.0        0
# 6      11.900400         0.0        0.0        0.0      22      0.0        0
# 7      12.396250         0.0        0.0        0.0      23      0.0        0
# ...

# %%
autos.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'baseModel',
#        'guzzler', 'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2',
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48351 entries, 0 to 48350
# Data columns (total 84 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        48351 non-null  float64
#  1   barrelsA08       48351 non-null  float64
#  2   charge120        48351 non-null  float64
#  3   charge240        48351 non-null  float64
#  4   city08           48351 non-null  int64
#  5   city08U          48351 non-null  float64
#  6   cityA08          48351 non-null  int64
#  7   cityA08U         48351 non-null  float64
#  8   cityCD           48351 non-null  float64
#  9   cityE            48351 non-null  float64
#  10  cityUF           48351 non-null  float64
#  11  co2              48351 non-null  int64
#  12  co2A             48351 non-null  int64
#  13  co2TailpipeAGpm  48351 non-null  float64
#  14  co2TailpipeGpm   48351 non-null  float64
#  15  comb08           48351 non-null  int64
# ...

# %%
cols = ['city08', 'comb08', 'highway08', 'cylinders', 'displ', 'drive', 'eng_dscr', 'fuelCost08', 'make', 'model', 'trany', 'range', 'createdOn', 'year']

# %%
autos[cols].dtypes
# Out:
# city08          int64
# comb08          int64
# highway08       int64
# cylinders     float64
# displ         float64
# drive          object
# eng_dscr       object
# fuelCost08      int64
# make           object
# model          object
# trany          object
# range           int64
# createdOn      object
# year            int64
# dtype: object

# %%
display(autos[cols])
# Out:
#        city08  comb08  highway08  cylinders  displ  \
# 0          19      21         25        4.0    2.0
# 1           9      11         14       12.0    4.9
# 2          23      27         33        4.0    2.2
# 3          10      11         12        8.0    5.2
# 4          17      19         23        4.0    2.2
# 5          21      22         24        4.0    1.8
# 6          22      25         29        4.0    1.8
# 7          23      24         26        4.0    1.6
# 8          23      26         31        4.0    1.6
# 9          23      25         30        4.0    1.8
# ...       ...     ...        ...        ...    ...
# 48341      18      20         24        4.0    2.1
# 48342      23      26         33        4.0    1.9
# 48343      21      24         30        4.0    1.9
# 48344      24      28         33        4.0    1.9
# 48345      21      25         32        4.0    1.9
# 48346      19      22         26        4.0    2.2
# ...

# %%
autos[cols].memory_usage(deep=True)
# Out:
# Index             132
# city08         386808
# comb08         386808
# highway08      386808
# cylinders      386808
# displ          386808
# drive         3175270
# eng_dscr      2306526
# fuelCost08     386808
# make          2675799
# model         2940287
# trany         3069142
# range          386808
# createdOn     3723027
# year           386808
# dtype: int64

# %%
autos[cols].memory_usage(deep=True).sum()
# Out:
# np.int64(20984647)

# %%
autos[cols].select_dtypes(int).describe()
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  48351.000000  48351.000000  48351.000000  48351.000000  48351.000000
# mean      20.115137     22.242063     25.959877   2527.220740      9.223015
# std       13.191759     12.298466     11.438098    776.097094     56.253988
# min        6.000000      7.000000      9.000000      0.000000      0.000000
# 25%       15.000000     17.000000     20.000000   2050.000000      0.000000
# 50%       18.000000     20.000000     24.000000   2500.000000      0.000000
# 75%       21.000000     24.000000     28.000000   3000.000000      0.000000
# max      153.000000    146.000000    142.000000   8400.000000    640.000000
#
#                year
# count  48351.000000
# mean    2004.655912
# std       12.711662
# min     1984.000000
# 25%     1993.000000
# 50%     2006.000000
# 75%     2016.000000
# max     2025.000000

# %%
# chaining
(autos
 [cols]
 .select_dtypes(int)
 .describe()
)
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  48351.000000  48351.000000  48351.000000  48351.000000  48351.000000
# mean      20.115137     22.242063     25.959877   2527.220740      9.223015
# std       13.191759     12.298466     11.438098    776.097094     56.253988
# min        6.000000      7.000000      9.000000      0.000000      0.000000
# 25%       15.000000     17.000000     20.000000   2050.000000      0.000000
# 50%       18.000000     20.000000     24.000000   2500.000000      0.000000
# 75%       21.000000     24.000000     28.000000   3000.000000      0.000000
# max      153.000000    146.000000    142.000000   8400.000000    640.000000
#
#                year
# count  48351.000000
# mean    2004.655912
# std       12.711662
# min     1984.000000
# 25%     1993.000000
# 50%     2006.000000
# 75%     2016.000000
# max     2025.000000

# %%
# can comb08 be and int8?
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
np.iinfo(np.int16)
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
# chaining
(autos
 [cols]
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16'})
 .select_dtypes([int, 'int8'])
 .describe()
)
# Out:
#           highway08    fuelCost08         range          year
# count  48351.000000  48351.000000  48351.000000  48351.000000
# mean      25.891047   2527.220740      9.223015   2004.655912
# std       11.562878    776.097094     56.253988     12.711662
# min     -128.000000      0.000000      0.000000   1984.000000
# 25%       20.000000   2050.000000      0.000000   1993.000000
# 50%       24.000000   2500.000000      0.000000   2006.000000
# 75%       28.000000   3000.000000      0.000000   2016.000000
# max      127.000000   8400.000000    640.000000   2025.000000

# %%
# floats
(autos
 [cols]
 .select_dtypes(float)
 .describe()
)
# Out:
#           cylinders         displ
# count  47266.000000  47268.000000
# mean       5.698388      3.270202
# std        1.772877      1.352909
# min        2.000000      0.000000
# 25%        4.000000      2.200000
# 50%        6.000000      3.000000
# 75%        6.000000      4.200000
# max       16.000000      8.400000
