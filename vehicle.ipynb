# %%
# %pip install matplotlib
# %pip install pandas
# %pip install IPython
# %matplotlib inline
from IPython.display import display
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (3.10.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sjvar\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: IPython in c:\users\sjvar\appdata\roaming\python\python313\site-packages (8.31.0)
# Requirement already satisfied: colorama in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from IPython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from IPython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from IPython) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from IPython) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from IPython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from IPython) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from jedi>=0.16->IPython) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from stack_data->IPython) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from stack_data->IPython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\sjvar\appdata\roaming\python\python313\site-packages (from stack_data->IPython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
pd.options.display.min_rows = 20

# %%
# %pip install openpyxl
import os

data_files = 'C:/Users/sjvar/Dev/pythondev/datasets/vehicles.xlsx'
if os.path.exists(data_files):
	autos = pd.read_excel(data_files)
	display(autos)
else:
	print(f"File not found: {data_files}")
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
#      Model Year             Mfr Name                          Division  \
# 0          2025         aston martin          Aston Martin Lagonda Ltd
# 1          2025                  BMW                               BMW
# 2          2025                  BMW                               BMW
# 3          2025                  BMW                               BMW
# 4          2025  Volkswagen Group of                           Bugatti
# 5          2025       General Motors                         Chevrolet
# 6          2025       General Motors                         Chevrolet
# 7          2025       General Motors                         Chevrolet
# 8          2025       General Motors                         Chevrolet
# 9          2025              Ferrari       Ferrari North America, Inc.
# ..          ...                  ...                               ...
# 634        2025              Porsche                           Porsche
# 635        2025              Porsche                           Porsche
# 636        2025              Porsche                           Porsche
# 637        2025          Rolls-Royce    Rolls-Royce Motor Cars Limited
# 638        2025          Rolls-Royce    Rolls-Royce Motor Cars Limited
# 639        2025               Subaru                            Subaru
# 640        2025               Subaru                            Subaru
# 641        2025               Toyota                            TOYOTA
# 642        2025                Volvo  Volvo Cars of North America, LLC
# 643        2025                Volvo  Volvo Cars of North America, LLC
#
#                                      Carline Verify Mfr Cd  \
# 0                                    Vantage           ASX
# 1                                    Z4 M40i           BMX
# 2                                    Z4 M40i           BMX
# 3                               Z4 sDrive30i           BMX
# 4                                    Mistral           VGA
# 5                                   CORVETTE           GMX
# 6                             CORVETTE E-RAY           GMX
# 7                               CORVETTE Z06           GMX
# 8                   CORVETTE Z06 CARBON AERO           GMX
# 9                                   F167 ABA           FEX
# ..                                       ...           ...
# 634                              Cayenne GTS           PRX
# 635                        Cayenne GTS Coupe           PRX
# 636                         Cayenne Turbo GT           PRX
# 637                     Black Badge Cullinan           RRG
# 638                                 Cullinan           RRG
# 639                               ASCENT AWD           FJX
# 640  ASCENT LIMITED/TOURING/ONYX EDITION AWD           FJX
# 641                              SEQUOIA 4WD           TYX
# 642                              XC90 B5 AWD           VVX
# 643                              XC90 B6 AWD           VVX
#
#      Index (Model Type Index)  Eng Displ  # Cyl Transmission  \
# 0                           2        4.0      8     Auto(A8)
# 1                         352        3.0      6     Auto(S8)
# 2                         353        3.0      6   Manual(M6)
# 3                         350        2.0      4     Auto(S8)
# 4                          48        8.0     16  Auto(AM-S7)
# 5                          50        6.2      8     Auto(S8)
# 6                          51        6.2      8     Auto(S8)
# 7                          55        5.5      8     Auto(S8)
# 8                          56        5.5      8     Auto(S8)
# 9                         167        6.5     12    Auto(AM8)
# ..                        ...        ...    ...          ...
# 634                       470        4.0      8     Auto(S8)
# 635                       471        4.0      8     Auto(S8)
# 636                       442        4.0      8     Auto(S8)
# 637                        11        6.7     12     Auto(S8)
# 638                        10        6.7     12     Auto(S8)
# 639                        33        2.4      4  Auto(AV-S8)
# 640                        34        2.4      4  Auto(AV-S8)
# 641                        40        3.4      6    Auto(S10)
# 642                       259        2.0      4     Auto(S8)
# 643                       243        2.0      4     Auto(S8)
#
#      City FE (Guide) - Conventional Fuel  ...  City CO2 Rounded Adjusted  \
# 0                                     15  ...                        579
# 1                                     23  ...                        386
# 2                                     19  ...                        469
# 3                                     25  ...                        351
# 4                                      8  ...                       1121
# 5                                     16  ...                        565
# 6                                     16  ...                        566
# 7                                     12  ...                        755
# 8                                     12  ...                        756
# 9                                     12  ...                        736
# ..                                   ...  ...                        ...
# 634                                   15  ...                        595
# 635                                   16  ...                        557
# 636                                   15  ...                        583
# 637                                   12  ...                        732
# 638                                   12  ...                        732
# 639                                   20  ...                        444
# 640                                   19  ...                        470
# 641                                   19  ...                        474
# 642                                   23  ...                        381
# 643                                   20  ...                        435
#
#      Hwy CO2 Rounded Adjusted  \
# 0                         399
# 1                         297
# 2                         332
# 3                         266
# 4                         726
# 5                         356
# 6                         368
# 7                         442
# 8                         478
# 9                         477
# ..                        ...
# 634                       410
# 635                       405
# 636                       444
# 637                       459
# 638                       459
# 639                       343
# 640                       356
# 641                       397
# 642                       298
# 643                       342
#
#      Comb CO2 Rounded Adjusted (as shown on FE Label)  \
# 0                                                 498
# 1                                                 346
# 2                                                 407
# 3                                                 312
# 4                                                 943
# 5                                                 471
# 6                                                 477
# 7                                                 614
# 8                                                 631
# 9                                                 619
# ..                                                ...
# 634                                               512
# 635                                               489
# 636                                               521
# 637                                               609
# 638                                               609
# 639                                               398
# 640                                               419
# 641                                               439
# 642                                               343
# 643                                               393
#
#      CO2-PHEV Composite Rounded Adjusted Combined CO2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# ..                                                ...
# 634                                               NaN
# 635                                               NaN
# 636                                               NaN
# 637                                               NaN
# 638                                               NaN
# 639                                               NaN
# 640                                               NaN
# 641                                               NaN
# 642                                               NaN
# 643                                               NaN
#
#      240V Charge Time at 240 volts (hours)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# ..                                     ...
# 634                                    NaN
# 635                                    NaN
# 636                                    NaN
# 637                                    NaN
# 638                                    NaN
# 639                                    NaN
# 640                                    NaN
# 641                                    NaN
# 642                                    NaN
# 643                                    NaN
#
#      120V Charge time at 120 Volts (hours)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# ..                                     ...
# 634                                    NaN
# 635                                    NaN
# 636                                    NaN
# 637                                    NaN
# 638                                    NaN
# 639                                    NaN
# 640                                    NaN
# 641                                    NaN
# 642                                    NaN
# 643                                    NaN
#
#      PHEV Total Driving Range (rounded to nearest 10 miles)DISTANCE  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# ..                                                 ...
# 634                                                NaN
# 635                                                NaN
# 636                                                NaN
# 637                                                NaN
# 638                                                NaN
# 639                                                NaN
# 640                                                NaN
# 641                                                NaN
# 642                                                NaN
# 643                                                NaN
#
#      City PHEV Composite MPGe Hwy PHEV Composite MPGe Comb PHEV Composite MPGe
# 0                         NaN                     NaN                      NaN
# 1                         NaN                     NaN                      NaN
# 2                         NaN                     NaN                      NaN
# 3                         NaN                     NaN                      NaN
# 4                         NaN                     NaN                      NaN
# 5                         NaN                     NaN                      NaN
# 6                         NaN                     NaN                      NaN
# 7                         NaN                     NaN                      NaN
# 8                         NaN                     NaN                      NaN
# 9                         NaN                     NaN                      NaN
# ..                        ...                     ...                      ...
# 634                       NaN                     NaN                      NaN
# 635                       NaN                     NaN                      NaN
# 636                       NaN                     NaN                      NaN
# 637                       NaN                     NaN                      NaN
# 638                       NaN                     NaN                      NaN
# 639                       NaN                     NaN                      NaN
# 640                       NaN                     NaN                      NaN
# 641                       NaN                     NaN                      NaN
# 642                       NaN                     NaN                      NaN
# 643                       NaN                     NaN                      NaN
#
# [644 rows x 162 columns]
